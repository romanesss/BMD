# %% [markdown]
# <h1>Візуалізація даних за допомогою бібліотеки Seaborn </h1>

# %% [markdown]
# <h1>Гаврилюк Р.В. БС-82</h1>

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.10.0-py3-none-any.whl (215 kB)
# Collecting matplotlib>=2.1.2
#   Using cached matplotlib-3.2.1-cp38-cp38-win_amd64.whl (9.2 MB)
# Collecting pandas>=0.22.0
#   Using cached pandas-1.0.3-cp38-cp38-win_amd64.whl (8.9 MB)
# Collecting scipy>=1.0.1
#   Using cached scipy-1.4.1-cp38-cp38-win_amd64.whl (31.0 MB)
# Collecting numpy>=1.13.3
#   Using cached numpy-1.18.2-cp38-cp38-win_amd64.whl (12.8 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.1.0-cp38-none-win_amd64.whl (57 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\roman\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.1.2->seaborn) (2.8.1)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Using cached pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pytz>=2017.2
#   Using cached pytz-2019.3-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: setuptools in c:\users\roman\appdata\local\programs\python\python38\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=2.1.2->seaborn) (41.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\roman\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.1->matplotlib>=2.1.2->seaborn) (1.14.0)
# Installing collected packages: kiwisolver, numpy, pyparsing, cycler, matplotlib, pytz, pandas, scipy, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.2.1 numpy-1.18.2 pandas-1.0.3 pyparsing-2.4.6 pytz-2019.3 scipy-1.4.1 seaborn-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()

# %%
sns.distplot(tips["total_bill"])

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np
sns.barplot(x='sex', y='total_bill',data=tips, estimator=np.median)

# %%
sns.boxplot(x="day", y="total_bill",data=tips, palette='rainbow')

# %%
sns.stripplot(x="day",y="total_bill", data=tips)

# %%
sns.heatmap(tips.corr())

# %%
import matplotlib.pyplot as plt
g=sns.FacetGrid(tips, col="time", row="smoker")
g=g.map(plt.hist,"total_bill")
