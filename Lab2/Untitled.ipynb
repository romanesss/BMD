# %% [markdown]
# <h1>Гаврилюк Роман Володимирович</h1>
# <h1>БС-82</h1>
# <h1>Обробка та аналіз БМД</h1>

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.1.3-cp38-cp38-win32.whl (8.9 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.1.0-cp38-none-win32.whl (43 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\roman\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib) (1.18.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\roman\appdata\local\programs\python\python38-32\lib\site-packages (from matplotlib) (2.8.1)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: setuptools in c:\users\roman\appdata\local\programs\python\python38-32\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (41.2.0)
# Requirement already satisfied: six in c:\users\roman\appdata\local\programs\python\python38-32\lib\site-packages (from cycler>=0.10->matplotlib) (1.14.0)
# Installing collected packages: kiwisolver, cycler, pyparsing, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.1.3 pyparsing-2.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0, 5, 11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1, 2, 1)
plt.plot(x,y,"r")

plt.subplot(1, 2, 2)
plt.plot(x,y,"b")

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])

axes.plot(x, y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1])
axes2 = fig.add_axes([0.1, 0.5, 0.4, 0.3])

axes1.plot(x, y, "r")
axes1.set_xlabel("X label")
axes1.set_ylabel("Y label")
axes1.set_title("Title")

axes2.plot(x, y, "b")
axes2.set_xlabel("X label")
axes2.set_ylabel("Y label")
axes2.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig,axes= plt.subplots()

axes.plot(x, y, "r")
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig,axes= plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig= plt.figure()
ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label="x**2")
ax.plot(x,x**3, label="x**3")
ax.legend()

# %%
fig=plt.figure(figsize=(8,4), dpi=100)

# %%
fig, ax= plt.subplots()
ax.plot(x,x**2, lw=2, ls= "--")

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, marker="o", markersize=10, markerfacecolor="y")

# %%
fig.savefig("imagine.png")

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([ 8., 10., 11.,  7., 11.,  9., 13., 10.,  6., 15.]),
#  array([  3. , 102.3, 201.6, 300.9, 400.2, 499.5, 598.8, 698.1, 797.4,
#         896.7, 996. ]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0, std, 100) for std in range (1,4)]
plt.boxplot(data, vert=True, patch_artist=True);
