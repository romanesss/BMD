# %% [markdown]
# <h1>Обробка та аналіз БМД  </h1>
# <h2>Гаврилюк Роман БС-82</h2>

# %%
import pandas as pd

# %% [markdown]
# <h2>Data Frame</h2>

# %%
new_df=pd.DataFrame(
{
     "brand":['Porsche ','Volkswagen','Vaz','Mazda','Volkswagen','Mercedes-Benz'],
     "type" :['911 Turbo S','Golf','2110','3','Touareg','AMG GT 63 S'] ,    
     "volume":['3.8','1.4tsi','1.6 16v','2i','3tdi v6','4.0 V8'],
     "year":[2015,2008,2004,2005,2016,2018],
     "horsepower":['580 Hp','190 Hp','100 Hp','150 Hp','200 Hp','639 Hp'],
     "body":['coupe','hatchback','sedan','sedan','crossover ','4-Door Coupe']
    
})
new_df
# Out:
#            brand         type   volume  year horsepower          body
# 0       Porsche   911 Turbo S      3.8  2015     580 Hp         coupe
# 1     Volkswagen         Golf   1.4tsi  2008     190 Hp     hatchback
# 2            Vaz         2110  1.6 16v  2004     100 Hp         sedan
# 3          Mazda            3       2i  2005     150 Hp         sedan
# 4     Volkswagen      Touareg  3tdi v6  2016     200 Hp    crossover
# 5  Mercedes-Benz  AMG GT 63 S   4.0 V8  2018     639 Hp  4-Door Coupe

# %% [markdown]
# File

# %%
path = "C:\\Users\\roman\\Desktop\\Jupyter\\Lab1\\top2018.csv"
data = pd.read_csv(path,encoding="utf-8")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <h2>Файл з директорії </h2>

# %%
import os
print("The directory we are working in is : {}".format(os.getcwd()))
# Out:
# The directory we are working in is : C:\Users\roman\Desktop\Jupyter\Lab1

# %%
data=pd.read_csv("C:\\Users\\roman\\Desktop\\Jupyter\\Lab1\\top2018.csv")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <h2>Відобразити дані</h2>

# %%
data
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %% [markdown]
# <h2>Базова статистика</h2>

# %%
data.shape
# Out:
# (100, 16)

# %%
data.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-036f5ae10232> in <module>
# ----> 1 data.head(-5)
#       2
#       3
#
# NameError: name 'data' is not defined

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
data.dtypes
# Out:
# id                   object
# name                 object
# artists              object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %% [markdown]
# <h1>Використання Describe</h1>

# %%
data.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count     100.00000  100.000000  100.000000  100.000000  100.000000
# mean        0.71646    0.659060    5.330000   -5.677640    0.590000
# std         0.13107    0.145067    3.676447    1.777577    0.494311
# min         0.25800    0.296000    0.000000  -10.109000    0.000000
# 25%         0.63550    0.562000    1.750000   -6.650500    0.000000
# 50%         0.73300    0.678000    5.000000   -5.566500    1.000000
# 75%         0.79825    0.772250    8.250000   -4.363750    1.000000
# max         0.96400    0.909000   11.000000   -2.384000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.115569      0.195701          0.001584    0.158302    0.484443
# std       0.104527      0.220946          0.013449    0.111662    0.206145
# ...

# %%
data['danceability'].describe()
# Out:
# count    100.00000
# mean       0.71646
# std        0.13107
# min        0.25800
# 25%        0.63550
# 50%        0.73300
# 75%        0.79825
# max        0.96400
# Name: danceability, dtype: float64

# %%
data['energy'].describe()
# Out:
# count    100.000000
# mean       0.659060
# std        0.145067
# min        0.296000
# 25%        0.562000
# 50%        0.678000
# 75%        0.772250
# max        0.909000
# Name: energy, dtype: float64

# %%
cut_data=data.iloc[0:10,:]
cut_data
# Out:
#                       id                          name        artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan          Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!   XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)    Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)    Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings          Drake
# 5  7dt6x5M1jzdTEt8oCbisT                    Better Now    Post Malone
# 6  58q2HKrzhC3ozto2nDdN4                     I Like It        Cardi B
# 7  7ef4DlsgrMEH11cDZd32M      One Kiss (with Dua Lipa)  Calvin Harris
# 8  76cy1WJvNGJTj78UqeA5z                         IDGAF       Dua Lipa
# 9  08bNPGLD8AhKpnnERrAc6                       FRIENDS     Marshmello
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449   7.0    -9.211   1.0       0.1090        0.0332
# ...

# %%
new_data = ["gr1","gr2","gr3","gr4","gr5","gr6","gr7","gr8","gr9","gr10"]
cut_data.insert(1,"Group",new_data)
cut_data
# Out:
#                       id Group                          name        artists  \
# 0  6DCZcSspjsKoFjzjrWoCd   gr1                    God's Plan          Drake
# 1  3ee8Jmje8o58CHK66QrVC   gr2                          SAD!   XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz   gr3    rockstar (feat. 21 Savage)    Post Malone
# 3  3swc6WTsr7rl9DqQKQA55   gr4  Psycho (feat. Ty Dolla $ign)    Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R   gr5                In My Feelings          Drake
# 5  7dt6x5M1jzdTEt8oCbisT   gr6                    Better Now    Post Malone
# 6  58q2HKrzhC3ozto2nDdN4   gr7                     I Like It        Cardi B
# 7  7ef4DlsgrMEH11cDZd32M   gr8      One Kiss (with Dua Lipa)  Calvin Harris
# 8  76cy1WJvNGJTj78UqeA5z   gr9                         IDGAF       Dua Lipa
# 9  08bNPGLD8AhKpnnERrAc6  gr10                       FRIENDS     Marshmello
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %% [markdown]
# <h1>Виведення статистики з розділенням на групи</h1>

# %%
cut_data.groupby('Group').describe()
# Out:
#       danceability                                               energy  \
#              count   mean std    min    25%    50%    75%    max  count
# Group
# gr1            1.0  0.754 NaN  0.754  0.754  0.754  0.754  0.754    1.0
# gr10           1.0  0.626 NaN  0.626  0.626  0.626  0.626  0.626    1.0
# gr2            1.0  0.740 NaN  0.740  0.740  0.740  0.740  0.740    1.0
# gr3            1.0  0.587 NaN  0.587  0.587  0.587  0.587  0.587    1.0
# gr4            1.0  0.739 NaN  0.739  0.739  0.739  0.739  0.739    1.0
# gr5            1.0  0.835 NaN  0.835  0.835  0.835  0.835  0.835    1.0
# gr6            1.0  0.680 NaN  0.680  0.680  0.680  0.680  0.680    1.0
# gr7            1.0  0.816 NaN  0.816  0.816  0.816  0.816  0.816    1.0
# gr8            1.0  0.791 NaN  0.791  0.791  0.791  0.791  0.791    1.0
# gr9            1.0  0.836 NaN  0.836  0.836  0.836  0.836  0.836    1.0
#
#               ... duration_ms           time_signature                     \
# ...

# %%
cut_data.to_csv("output.csv",encoding='utf-8')
